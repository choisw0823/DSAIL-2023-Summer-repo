# %%
genres = ['unknown', 'Action', 'Adventure','Animation', "Children's", 'Comedy', 'Crime','Documentary','Drama','Fantasy','Film-Noir','Horror','Musical','Mystery','Romance','Sci-Fi','Thriller','War','Western']
occupations = ['administrator','artist','doctor','educator','engineer','entertainment',
               'executive','healthcare','homemaker','lawyer','librarian','marketing','none',
               'other','programmer','retired','salesman','scientist','student','technician','writer']

from google.colab import drive
import pandas as pd

drive.mount('/content/drive', force_remount=True)

# specify the path in your Drive
save_path = "/content/drive/MyDrive/ml-100k/"


# load dataset
ratings_df = pd.read_csv(save_path+'u.data', sep='\t', header=None, names=['userId', 'movieId', 'rating', 'timestamp'], engine='python', encoding='latin')
movies_df = pd.read_csv(save_path+'u.item', sep='|', header=None, names=['movieId', 'title', 'release_date', 'video_release_date', 'IMDB']+genres, engine='python', encoding='latin')
users_df = pd.read_csv(save_path+'u.user', sep='|', header=None, names=['userId', 'age', 'gender', 'occupation', 'zip_code'], engine='python')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder

movies_df['title'] = movies_df['title'].str.rsplit(' (', 1).str[0]
users_df.drop(columns=['zip_code'], inplace=True)
users_df['gender'] = users_df['gender'].apply(lambda x: 0 if x == 'M' else 1)

genres = list(movies_df.columns[2:])
movies_df['genres'] = movies_df[genres].apply(lambda x: list(x.index[x.values == 1]), axis=1)
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'])
movies_df['movie_age'] = (pd.Timestamp.now() - movies_df['release_date']).dt.days / 365.25
# Min-Max scaling for movie_age
movies_df['movie_age'] = (movies_df['movie_age'] - movies_df['movie_age'].min()) / (movies_df['movie_age'].max() - movies_df['movie_age'].min())

ratings_df = ratings_df.sort_values(by='timestamp')
ratings_df['liked'] = ratings_df['rating'].apply(lambda x: 1 if x >= 3 else 0)

liked_movies_dict = ratings_df[ratings_df['liked'] == 1].groupby('userId')['movieId'].apply(list).to_dict()
disliked_movies_dict = ratings_df[ratings_df['liked'] == 0].groupby('userId')['movieId'].apply(list).to_dict()
watched_movies_dict = ratings_df.groupby('userId')['movieId'].apply(list).to_dict()

users_df['liked_movies'] = users_df['userId'].map(liked_movies_dict)
users_df['disliked_movies'] = users_df['userId'].map(disliked_movies_dict)
users_df['watched_movies'] = users_df['userId'].map(watched_movies_dict)

movies_df.set_index('movieId', inplace=True)

watched_genres_dict = {user_id: list(set([genre for movie in movies for genre in movies_df.loc[movie]['genres']])) for user_id, movies in watched_movies_dict.items()}
users_df['watched_genres'] = users_df['userId'].map(watched_genres_dict)

watched_movie_age_dict = {user_id: [movies_df.loc[movie]['movie_age'] for movie in movies] for user_id, movies in watched_movies_dict.items()}
users_df['watched_movie_age'] = users_df['userId'].map(watched_movie_age_dict)

liked_movie_age_dict = {user_id: [movies_df.loc[movie]['movie_age'] for movie in movies] for user_id, movies in liked_movies_dict.items()}
users_df['liked_movie_age'] = users_df['userId'].map(liked_movie_age_dict)

def avg_with_nan_replacement(lst):
    if lst and all(isinstance(i, (int, float)) for i in lst):
        mean_val = np.nanmean(lst)
        lst = [mean_val if np.isnan(i) else i for i in lst]
    return lst

watched_movie_age_dict = {user_id: avg_with_nan_replacement([movies_df.loc[movie]['movie_age'] for movie in movies]) for user_id, movies in watched_movies_dict.items()}
users_df['watched_movie_age'] = users_df['userId'].map(watched_movie_age_dict)

liked_movie_age_dict = {user_id: avg_with_nan_replacement([movies_df.loc[movie]['movie_age'] for movie in movies]) for user_id, movies in liked_movies_dict.items()}
users_df['liked_movie_age'] = users_df['userId'].map(liked_movie_age_dict)

# Min-Max scaling
users_df['age'] = (users_df['age'] - users_df['age'].min()) / (users_df['age'].max() - users_df['age'].min())

occupations = users_df['occupation'].unique().tolist()
occupation_dict = {occupation: index for index, occupation in enumerate(occupations)}
users_df['occupation'] = users_df['occupation'].map(occupation_dict)

genre_dict = {genre: index for index, genre in enumerate(genres)}
users_df['watched_genres'] = users_df['watched_genres'].apply(lambda x: [genre_dict[genre] for genre in x])

WINDOW_SIZE = 10
TARGET = 'liked_movies'

def extract_windows_and_labels(row):
    windows = []
    labels = []
    labels_like = []
    avg_liked_movie_ages = []

    if isinstance(row[TARGET], list):
        if len(row[TARGET]) > WINDOW_SIZE:
            for i in range(len(row[TARGET]) - WINDOW_SIZE):
                windows.append(row[TARGET][i:i+WINDOW_SIZE])
                avg_liked_movie_ages.append((row['liked_movie_age'][i+WINDOW_SIZE]))
                next_movie = row[TARGET][i+WINDOW_SIZE]
                labels.append(next_movie)
                labels_like.append(1 if isinstance(row['liked_movies'], list) and next_movie in row['liked_movies'] else 0)
        # else:
        #     windows.append(row[TARGET][:-1])
        #     avg_liked_movie_ages.append(np.mean(row['liked_movie_age']))
        #     labels.append(row[TARGET][-1])
        #     labels_like.append(1 if isinstance(row['liked_movies'], list) and row[TARGET][-1] in row['liked_movies'] else 0)

    return pd.Series([windows, labels, labels_like, avg_liked_movie_ages])

users_df[['windows', 'labels', 'labels_like', 'avg_liked_movie_age']] = users_df.apply(extract_windows_and_labels, axis=1)

expanded_df = users_df.explode('windows').reset_index(drop=True)
labels_df = expanded_df.explode('labels').reset_index(drop=True)
labels_like_df = expanded_df.explode('labels_like').reset_index(drop=True)

expanded_df['labels'] = labels_df['labels']
expanded_df['labels_like'] = labels_like_df['labels_like']

expanded_df['avg_liked_movie_age'] = expanded_df.explode('avg_liked_movie_age').reset_index(drop=True)['avg_liked_movie_age']
expanded_df['avg_liked_movie_age'] = expanded_df['avg_liked_movie_age'].astype('float64')

expanded_df['disliked_movies'] = expanded_df['disliked_movies'].apply(lambda x: [] if isinstance(x, float) else x)

def handle_nan(x):
    if isinstance(x, (list, np.ndarray)):
        return x
    elif pd.isnull(x):
        return []
    else:
        return [x]

expanded_df['disliked_movies'] = expanded_df['disliked_movies'].apply(handle_nan)

# Adding user features
gender_ohe = OneHotEncoder()
gender_encoded = gender_ohe.fit_transform(users_df[['gender']]).toarray()

occupation_ohe = OneHotEncoder()
occupation_encoded = occupation_ohe.fit_transform(users_df[['occupation']]).toarray()

combined_features = np.hstack((gender_encoded, users_df[['age']].values, occupation_encoded))
users_df['user_feat'] = combined_features.tolist()

# Adding 'user_feat' to the 'expanded_df'
expanded_df['user_feat'] = expanded_df['userId'].map(users_df.set_index('userId')['user_feat'])
# # 'userId'와 'movieId'가 공통 키인 경우
# # 'userId'와 'labels'가 병합의 키인 경우
# expanded_df = expanded_df.merge(ratings_df[['userId', 'movieId', 'rating']],
#                                 left_on=['userId', 'labels'],
#                                 right_on=['userId', 'movieId'],
#                                 how='left').drop(columns=['movieId'])



expanded_df = expanded_df.dropna()
# Assuming the lists are in string format, we convert them to lists
# Create a condition for the rows to be kept
condition = (expanded_df['disliked_movies'].str.len() > 10) & (expanded_df['liked_movies'].str.len() > 15)

# Keep only the rows that satisfy the condition
expanded_df = expanded_df[condition]



# Compute the number of rows for each user
row_counts_per_user = expanded_df.groupby('userId').size()

# Compute summary statistics
statistics = row_counts_per_user.describe()

# Display the statistics
print(f"Max: {statistics['max']}")
print(f"75th percentile: {statistics['75%']}")
print(f"Median: {statistics['50%']}")
print(f"25th percentile: {statistics['25%']}")
print(f"Min: {statistics['min']}")

# Compute the number of rows for each user
row_counts_per_user = expanded_df.groupby('userId').size()

# Filter out users with less than 68 rows
users_to_keep = row_counts_per_user[row_counts_per_user >= 100].index

# Keep only the rows with 'userId' in 'users_to_keep'
filtered_df = expanded_df[expanded_df['userId'].isin(users_to_keep)]
expanded_df = filtered_df
expanded_df


users_df['disliked_movies'] = users_df['disliked_movies'].apply(lambda x: [] if isinstance(x, float) else x)

def handle_nan(x):
    if isinstance(x, (list, np.ndarray)):
        return x
    elif pd.isnull(x):
        return []
    else:
        return [x]

expanded_df['disliked_movies'] = expanded_df['disliked_movies'].apply(handle_nan)

liked_movies_lengths = users_df['liked_movies'].apply(len)
disliked_movies_lengths = users_df['disliked_movies'].apply(len)

print("Liked Movies Lengths:")
print(f"Max: {liked_movies_lengths.max()}")
print(f"75%: {liked_movies_lengths.quantile(0.75)}")
print(f"Median: {liked_movies_lengths.median()}")
print(f"25%: {liked_movies_lengths.quantile(0.25)}")
print(f"Min: {liked_movies_lengths.min()}")

print("\nDisliked Movies Lengths:")
print(f"Max: {disliked_movies_lengths.max()}")
print(f"75%: {disliked_movies_lengths.quantile(0.75)}")
print(f"Median: {disliked_movies_lengths.median()}")
print(f"25%: {disliked_movies_lengths.quantile(0.25)}")
print(f"Min: {disliked_movies_lengths.min()}")


num_unique_users = expanded_df['userId'].nunique()
print(f"Number of unique users: {num_unique_users}")
# Out:
# <ipython-input-29-94ae6f1a3f62>:5: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   movies_df['title'] = movies_df['title'].str.rsplit(' (', 1).str[0]
# Max: 499.0
# 75th percentile: 186.0
# Median: 116.0
# 25th percentile: 68.0
# Min: 6.0
# Liked Movies Lengths:
# Max: 509
# 75%: 123.5
# Median: 55.0
# 25%: 27.0
# Min: 6
#
# Disliked Movies Lengths:
# Max: 558
# 75%: 21.0
# Median: 9.0
# 25%: 4.0
# Min: 0
# Number of unique users: 243

# %%
expanded_df
# Out:
#        userId       age  gender  occupation  \
# 0           1  0.257576       0           0
# 1           1  0.257576       0           0
# 2           1  0.257576       0           0
# 3           1  0.257576       0           0
# 4           1  0.257576       0           0
# ...       ...       ...     ...         ...
# 73098     943  0.227273       0           5
# 73099     943  0.227273       0           5
# 73100     943  0.227273       0           5
# 73101     943  0.227273       0           5
# 73102     943  0.227273       0           5
#
#                                             liked_movies  \
# 0      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 1      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 2      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 3      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 4      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# ...                                                  ...
# 73098  [64, 181, 28, 174, 100, 127, 508, 763, 50, 475...
# 73099  [64, 181, 28, 174, 100, 127, 508, 763, 50, 475...
# 73100  [64, 181, 28, 174, 100, 127, 508, 763, 50, 475...
# 73101  [64, 181, 28, 174, 100, 127, 508, 763, 50, 475...
# 73102  [64, 181, 28, 174, 100, 127, 508, 763, 50, 475...
#
#                                          disliked_movies  \
# 0      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 1      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 2      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 3      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 4      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# ...                                                  ...
# 73098  [1067, 412, 1028, 756, 1047, 284, 831, 1011, 1...
# 73099  [1067, 412, 1028, 756, 1047, 284, 831, 1011, 1...
# 73100  [1067, 412, 1028, 756, 1047, 284, 831, 1011, 1...
# 73101  [1067, 412, 1028, 756, 1047, 284, 831, 1011, 1...
# 73102  [1067, 412, 1028, 756, 1047, 284, 831, 1011, 1...
#
#                                           watched_movies  \
# 0      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 1      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 2      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 3      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# 4      [168, 172, 165, 156, 166, 196, 187, 14, 250, 1...
# ...                                                  ...
# 73098  [64, 181, 28, 174, 100, 1067, 127, 508, 763, 5...
# 73099  [64, 181, 28, 174, 100, 1067, 127, 508, 763, 5...
# 73100  [64, 181, 28, 174, 100, 1067, 127, 508, 763, 5...
# 73101  [64, 181, 28, 174, 100, 1067, 127, 508, 763, 5...
# 73102  [64, 181, 28, 174, 100, 1067, 127, 508, 763, 5...
#
#                                           watched_genres  \
# 0      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...
# 1      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...
# 2      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...
# 3      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...
# 4      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...
# ...                                                  ...
# 73098  [9, 18, 16, 4, 11, 17, 12, 19, 15, 7, 14, 20, ...
# 73099  [9, 18, 16, 4, 11, 17, 12, 19, 15, 7, 14, 20, ...
# 73100  [9, 18, 16, 4, 11, 17, 12, 19, 15, 7, 14, 20, ...
# 73101  [9, 18, 16, 4, 11, 17, 12, 19, 15, 7, 14, 20, ...
# 73102  [9, 18, 16, 4, 11, 17, 12, 19, 15, 7, 14, 20, ...
#
#                                        watched_movie_age  \
# 0      [0.3229842446709916, 0.24488486490340053, 0.16...
# 1      [0.3229842446709916, 0.24488486490340053, 0.16...
# 2      [0.3229842446709916, 0.24488486490340053, 0.16...
# 3      [0.3229842446709916, 0.24488486490340053, 0.16...
# 4      [0.3229842446709916, 0.24488486490340053, 0.16...
# ...                                                  ...
# 73098  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73099  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73100  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73101  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73102  [0.06259356954444996, 0.02095957795679758, 0.0...
#
#                                          liked_movie_age  \
# 0      [0.3229842446709916, 0.24488486490340053, 0.16...
# 1      [0.3229842446709916, 0.24488486490340053, 0.16...
# 2      [0.3229842446709916, 0.24488486490340053, 0.16...
# 3      [0.3229842446709916, 0.24488486490340053, 0.16...
# 4      [0.3229842446709916, 0.24488486490340053, 0.16...
# ...                                                  ...
# 73098  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73099  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73100  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73101  [0.06259356954444996, 0.02095957795679758, 0.0...
# 73102  [0.06259356954444996, 0.02095957795679758, 0.0...
#
#                                                  windows labels labels_like  \
# 0      [168, 172, 165, 156, 166, 196, 187, 14, 250, 127]    181           1
# 1      [172, 165, 156, 166, 196, 187, 14, 250, 127, 181]    117           1
# 2      [165, 156, 166, 196, 187, 14, 250, 127, 181, 117]    109           1
# 3      [156, 166, 196, 187, 14, 250, 127, 181, 117, 109]      1           1
# 4        [166, 196, 187, 14, 250, 127, 181, 117, 109, 1]    246           1
# ...                                                  ...    ...         ...
# 73098  [722, 38, 765, 1074, 1188, 41, 1228, 373, 796,...    211           1
# 73099  [38, 765, 1074, 1188, 41, 1228, 373, 796, 237,...    469           1
# 73100  [765, 1074, 1188, 41, 1228, 373, 796, 237, 133...    525           1
# 73101  [1074, 1188, 41, 1228, 373, 796, 237, 1330, 15...    197           1
# 73102  [1188, 41, 1228, 373, 796, 237, 1330, 151, 840...    482           1
#
#        avg_liked_movie_age                                          user_feat
# 0                 0.020960  [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...
# 1                 0.030940  [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...
# 2                 0.032687  [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...
# 3                 0.049583  [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...
# 4                 0.023526  [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...
# ...                    ...                                                ...
# 73098             0.375062  [1.0, 0.0, 0.22727272727272727, 0.0, 0.0, 0.0,...
# 73099             0.075604  [1.0, 0.0, 0.22727272727272727, 0.0, 0.0, 0.0,...
# 73100             0.687531  [1.0, 0.0, 0.22727272727272727, 0.0, 0.0, 0.0,...
# 73101             0.414130  [1.0, 0.0, 0.22727272727272727, 0.0, 0.0, 0.0,...
# 73102             0.518286  [1.0, 0.0, 0.22727272727272727, 0.0, 0.0, 0.0,...
#
# [45196 rows x 15 columns]

# %%
selected_df = expanded_df[['userId', 'windows', 'disliked_movies', 'watched_genres', 'labels', 'user_feat']].copy()
selected_df['example_age'] = expanded_df['avg_liked_movie_age']
selected_df
# Out:
#        userId                                            windows  \
# 0           1  [168, 172, 165, 156, 166, 196, 187, 14, 250, 127]
# 1           1  [172, 165, 156, 166, 196, 187, 14, 250, 127, 181]
# 2           1  [165, 156, 166, 196, 187, 14, 250, 127, 181, 117]
# 3           1  [156, 166, 196, 187, 14, 250, 127, 181, 117, 109]
# 4           1    [166, 196, 187, 14, 250, 127, 181, 117, 109, 1]
# ...       ...                                                ...
# 72313     932  [389, 709, 228, 566, 222, 663, 161, 1065, 617,...
# 72315     932  [228, 566, 222, 663, 161, 1065, 617, 167, 1411...
# 72318     932  [663, 161, 1065, 617, 167, 1411, 708, 121, 676...
# 72320     932  [1065, 617, 167, 1411, 708, 121, 676, 399, 103...
# 72322     932  [167, 1411, 708, 121, 676, 399, 1035, 155, 414...
#
#                                          disliked_movies  \
# 0      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 1      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 2      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 3      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# 4      [245, 260, 264, 126, 237, 11, 8, 143, 94, 145,...
# ...                                                  ...
# 72313  [890, 640, 64, 841, 235, 385, 550, 541, 679, 1...
# 72315  [890, 640, 64, 841, 235, 385, 550, 541, 679, 1...
# 72318  [890, 640, 64, 841, 235, 385, 550, 541, 679, 1...
# 72320  [890, 640, 64, 841, 235, 385, 550, 541, 679, 1...
# 72322  [890, 640, 64, 841, 235, 385, 550, 541, 679, 1...
#
#                                           watched_genres labels  \
# 0      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...    181
# 1      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...    117
# 2      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...    109
# 3      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...      1
# 4      [18, 11, 12, 10, 5, 8, 9, 19, 15, 7, 14, 20, 1...    246
# ...                                                  ...    ...
# 72313  [9, 16, 18, 11, 4, 17, 12, 19, 15, 13, 7, 14, ...    528
# 72315  [9, 16, 18, 11, 4, 17, 12, 19, 15, 13, 7, 14, ...    491
# 72318  [9, 16, 18, 11, 4, 17, 12, 19, 15, 13, 7, 14, ...    506
# 72320  [9, 16, 18, 11, 4, 17, 12, 19, 15, 13, 7, 14, ...    517
# 72322  [9, 16, 18, 11, 4, 17, 12, 19, 15, 13, 7, 14, ...    134
#
#                                                user_feat  example_age
# 0      [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...     0.020960
# 1      [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...     0.030940
# 2      [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...     0.032687
# 3      [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...     0.049583
# 4      [1.0, 0.0, 0.25757575757575757, 1.0, 0.0, 0.0,...     0.023526
# ...                                                  ...          ...
# 72313  [1.0, 0.0, 0.7727272727272727, 0.0, 0.0, 0.0, ...     0.192807
# 72315  [1.0, 0.0, 0.7727272727272727, 0.0, 0.0, 0.0, ...     0.791687
# 72318  [1.0, 0.0, 0.7727272727272727, 0.0, 0.0, 0.0, ...     0.570364
# 72320  [1.0, 0.0, 0.7727272727272727, 0.0, 0.0, 0.0, ...     0.257895
# 72322  [1.0, 0.0, 0.7727272727272727, 0.0, 0.0, 0.0, ...     0.752620
#
# [11726 rows x 7 columns]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
class CandidateGeneration(nn.Module):
    def __init__(self, n_movies, n_genres, embedding_dim):
        super(CandidateGeneration, self).__init__()

        self.genre_embedding_dim = 16
        self.user_embedding_dim = 24
        self.n_movies = n_movies
        self.movie_embedding = nn.Embedding(n_movies+1, embedding_dim, padding_idx=0).to(device)
        self.genre_embedding = nn.Embedding(n_genres, self.genre_embedding_dim).to(device)
        self.l2_norm = nn.LayerNorm(embedding_dim).to(device)
        self.l2_norm2 = nn.LayerNorm(self.genre_embedding_dim).to(device)

        # Rest of your code


        self.dense_1 = nn.Linear(embedding_dim + self.genre_embedding_dim + self.user_embedding_dim  + 1 , 512)
        self.batch_norm_1 = nn.BatchNorm1d(512)
        self.dense_2 = nn.Linear(512, 256)
        self.batch_norm_2 = nn.BatchNorm1d(256)
        self.dense_3 = nn.Linear(256, 128)
        self.batch_norm_3 = nn.BatchNorm1d(128)
        self.dense_output = nn.Linear(128, embedding_dim)

    def forward(self, windows, watched_genres, user_feat, watched_movie_age):


        windows_embedded = self.movie_embedding(windows)
        windows_embedded = self.l2_norm(windows_embedded)
        windows_embedded = windows_embedded.mean(dim=1)

        watched_genres = self.genre_embedding(watched_genres)
        watched_genres = self.l2_norm2(watched_genres)
        watched_genres = watched_genres.mean(dim=1)

        windows_embedded = windows_embedded.float()
        watched_genres = watched_genres.float()
        watched_movie_age = watched_movie_age.float()
        user_feat = user_feat.float()

        # concatenate all the embeddings

        x = torch.cat([windows_embedded, watched_genres, user_feat, watched_movie_age ], dim=1)
        # Pass through dense layers with ReLU and Batch Norm
        x = torch.relu(self.batch_norm_1(self.dense_1(x)))
        x = torch.relu(self.batch_norm_2(self.dense_2(x)))
        x = torch.relu(self.batch_norm_3(self.dense_3(x)))

        # Output layer
        user_embedding = self.dense_output(x)
        return user_embedding



    def loss(self, user_embedding, target_movies, negative_samples):
        target_movie_embeddings = self.movie_embedding(target_movies)
        negative_movie_embeddings = self.movie_embedding(negative_samples)

        target_scores = (user_embedding * target_movie_embeddings).sum(dim=1)
        negative_scores = (user_embedding.unsqueeze(1) * negative_movie_embeddings).sum(dim=-1)
        logits = torch.cat([target_scores, negative_scores], dim=1)
        targets = torch.zeros(logits.shape[0], dtype=torch.long, device=logits.device)

        loss_fn = nn.CrossEntropyLoss()
        loss = loss_fn(logits, targets)

        return loss
# Out:
# cpu

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from sklearn.model_selection import GroupShuffleSplit, KFold
from torch.optim.lr_scheduler import ReduceLROnPlateau
from copy import deepcopy

class MovieDataset(Dataset):
    def __init__(self, user_df):
        self.user_df = user_df

    def __len__(self):
        return len(self.user_df)

    def __getitem__(self, idx):
        user = self.user_df.iloc[idx]
        try:
          windows = torch.tensor(user['windows'], dtype=torch.long)
        except:
          print(user['windows'])
        watched_genres = torch.tensor(user['watched_genres'], dtype=torch.long)
        disliked_movies = torch.tensor(user['disliked_movies'], dtype=torch.long)


        def pad_or_truncate(tensor, max_length):
            if len(tensor) < max_length:
                padding = torch.zeros(max_length - len(tensor), *tensor.shape[1:], dtype=tensor.dtype)
                tensor = torch.cat((tensor, padding))
            else:
                tensor = tensor[:max_length]
            return tensor

        windows = pad_or_truncate(windows, WINDOW_SIZE)
        disliked_movies = pad_or_truncate(disliked_movies, 10)

        watched_genres = pad_or_truncate(watched_genres, 19)
        user_id = torch.tensor([user['userId']])
        #labels = pad_or_truncate(labels, self.max_seq_length)
        #labels_like = pad_or_truncate(labels_like, self.max_seq_length)
        labels = torch.tensor([user['labels']])
        labels_like = torch.tensor([user['labels_like']])
        watched_movie_age = torch.tensor([user['avg_liked_movie_age']])
        user_feat = torch.tensor(user['user_feat'])
        return user_id, windows, watched_genres, watched_movie_age, user_feat, labels, labels_like, disliked_movies





def split_data(df, test_ratio=0.05):
    train_data = []
    test_data = []

    for _, group in df.groupby('userId'):
        cutoff = int((1.0 - test_ratio) * len(group))
        train = group.iloc[:cutoff]
        test = group.iloc[cutoff:]

        train_data.append(train)
        test_data.append(test)
    return pd.concat(train_data), pd.concat(test_data)



# Hyperparameters
n_movies = len(movies_df)
n_genres = len(genres)
n_genders = 2
n_occupations = len(occupations)
embedding_dim = 128
batch_size = 32
epochs = 100
lr = 0.01
max_seq_length = 400


# Split the dataset into training and testing sets
train_df, test_df = split_data(expanded_df)
train_dataset = MovieDataset(train_df)
test_dataset = MovieDataset(test_df)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Model and optimizer
model = CandidateGeneration(n_movies, n_genres, embedding_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
saved_weights = {}

# Training loop
for epoch in range(epochs):
    total_loss = 0

    for batch_num, ( user_ids, windows, watched_genres, watched_movie_age, user_feat, labels, labels_like, disliked_movies) in enumerate(train_dataloader, 1):
        # Move data to GPU
        user_ids, windows, watched_genres, watched_movie_age, user_feat, labels, disliked_movies = user_ids.to(device), windows.to(device), watched_genres.to(device), watched_movie_age.to(device), user_feat.to(device),  labels.to(device),disliked_movies.to(device)

        optimizer.zero_grad()

        output = model(windows, watched_genres, user_feat, watched_movie_age)
        loss = model.loss(output, labels, disliked_movies)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        if batch_num % 100 == 0:
            print(f"Epoch {epoch+1}/{epochs}, Batch {batch_num}/{len(train_dataloader)}, Batch Loss: {loss.item()}")

    epoch_loss = total_loss / len(train_dataloader)
    print(f"Epoch {epoch+1}/{epochs}, Average Loss: {epoch_loss}")
    saved_weights[epoch] = model.movie_embedding.weight.detach().clone()
    if epoch > 0:
        # Find the rows that have changed
        changed_rows = (saved_weights[epoch] != saved_weights[epoch-1]).any(dim=1)
        # Print the indices of the changed rows
        print(f"Changed rows in epoch {epoch}: {changed_rows.nonzero(as_tuple=True)[0]}")
        print(model.movie_embedding.weight)

    # Testing loop
    total_test_loss = 0
    for  batch_num, ( user_ids, windows, watched_genres, watched_movie_age, user_feat, labels, labels_like, disliked_movies) in enumerate(test_dataloader, 1):
        # Move data to GPU
        user_ids, windows, watched_genres, watched_movie_age, user_feat, labels, disliked_movies = user_ids.to(device), windows.to(device), watched_genres.to(device), watched_movie_age.to(device), user_feat.to(device),  labels.to(device),disliked_movies.to(device)

        with torch.no_grad():
            output = model(windows, watched_genres, user_feat, watched_movie_age)
            loss = model.loss(output, labels, disliked_movies)
            total_test_loss += loss.item()

    average_test_loss = total_test_loss / len(test_dataloader)
    print(f"Test Loss: {average_test_loss}")
# Out:
# Epoch 1/100, Batch 100/1338, Batch Loss: 4.4243621826171875
# Epoch 1/100, Batch 200/1338, Batch Loss: 4.864561080932617
# Epoch 1/100, Batch 300/1338, Batch Loss: 2.8402206897735596
# Epoch 1/100, Batch 400/1338, Batch Loss: 1.9792455434799194
# Epoch 1/100, Batch 500/1338, Batch Loss: 1.8518508672714233
# Epoch 1/100, Batch 600/1338, Batch Loss: 0.6283324956893921
# Epoch 1/100, Batch 700/1338, Batch Loss: 0.0013867157977074385
# Epoch 1/100, Batch 800/1338, Batch Loss: 0.004879412706941366
# Epoch 1/100, Batch 900/1338, Batch Loss: 0.6647571325302124
# Epoch 1/100, Batch 1000/1338, Batch Loss: 0.021728891879320145
# Epoch 1/100, Batch 1100/1338, Batch Loss: 0.0007691372884437442
# Epoch 1/100, Batch 1200/1338, Batch Loss: 0.000269660959020257
# Epoch 1/100, Batch 1300/1338, Batch Loss: 8.648981747683138e-05
# Epoch 1/100, Average Loss: 2.072298743354871
# Test Loss: 0.03190034653112283
# Epoch 2/100, Batch 100/1338, Batch Loss: 0.00010571196617092937
# Epoch 2/100, Batch 200/1338, Batch Loss: 0.0006189148407429457
# Epoch 2/100, Batch 300/1338, Batch Loss: 8.653280383441597e-05
# Epoch 2/100, Batch 400/1338, Batch Loss: 0.0001602276461198926
# Epoch 2/100, Batch 500/1338, Batch Loss: 0.00033783461549319327
# Epoch 2/100, Batch 600/1338, Batch Loss: 0.00024198427854571491
# Epoch 2/100, Batch 700/1338, Batch Loss: 0.0003286059945821762
# Epoch 2/100, Batch 800/1338, Batch Loss: 0.0001770303351804614
# Epoch 2/100, Batch 900/1338, Batch Loss: 0.00016281459829770029
# Epoch 2/100, Batch 1000/1338, Batch Loss: 3.5715303965844214e-05
# Epoch 2/100, Batch 1100/1338, Batch Loss: 3.2316653232555836e-05
# Epoch 2/100, Batch 1200/1338, Batch Loss: 8.021309622563422e-05
# Epoch 2/100, Batch 1300/1338, Batch Loss: 6.530065002152696e-05
# Epoch 2/100, Average Loss: 0.004777854041528048
# Changed rows in epoch 1: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.5964,  0.4605, -0.4531,  ..., -0.3911,  1.1814,  0.0784],
#         [ 0.8771, -0.0427, -0.2202,  ...,  1.3985,  0.0697,  0.1340],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7579, -0.2044, -0.3426,  ...,  0.1120,  0.9949, -1.4577],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 0.013837441483977576
# Epoch 3/100, Batch 100/1338, Batch Loss: 0.0005359129281714559
# Epoch 3/100, Batch 200/1338, Batch Loss: 6.789521285099909e-05
# Epoch 3/100, Batch 300/1338, Batch Loss: 9.802114800550044e-05
# Epoch 3/100, Batch 400/1338, Batch Loss: 5.768470873590559e-05
# Epoch 3/100, Batch 500/1338, Batch Loss: 6.754502828698605e-05
# Epoch 3/100, Batch 600/1338, Batch Loss: 6.343980203382671e-05
# Epoch 3/100, Batch 700/1338, Batch Loss: 6.239765207283199e-05
# Epoch 3/100, Batch 800/1338, Batch Loss: 3.173538425471634e-05
# Epoch 3/100, Batch 900/1338, Batch Loss: 3.6730671126861125e-06
# Epoch 3/100, Batch 1000/1338, Batch Loss: 1.0501274118723813e-05
# Epoch 3/100, Batch 1100/1338, Batch Loss: 1.668895151851757e-06
# Epoch 3/100, Batch 1200/1338, Batch Loss: 1.2408594557200558e-05
# Epoch 3/100, Batch 1300/1338, Batch Loss: 4.62579118902795e-05
# Epoch 3/100, Average Loss: 0.0016407307235563125
# Changed rows in epoch 2: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6047,  0.4574, -0.4612,  ..., -0.3773,  1.1798,  0.0750],
#         [ 0.8771, -0.0427, -0.2209,  ...,  1.3982,  0.0699,  0.1340],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7578, -0.2045, -0.3427,  ...,  0.1121,  0.9949, -1.4579],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 0.003607859819838571
# Epoch 4/100, Batch 100/1338, Batch Loss: 7.185953109001275e-06
# Epoch 4/100, Batch 200/1338, Batch Loss: 2.4325852336914977e-06
# Epoch 4/100, Batch 300/1338, Batch Loss: 3.956371801905334e-05
# Epoch 4/100, Batch 400/1338, Batch Loss: 1.7581734937266447e-05
# Epoch 4/100, Batch 500/1338, Batch Loss: 1.054930362442974e-05
# Epoch 4/100, Batch 600/1338, Batch Loss: 1.7467347788624465e-05
# Epoch 4/100, Batch 700/1338, Batch Loss: 7.450580152834618e-09
# Epoch 4/100, Batch 800/1338, Batch Loss: 2.9802311729554276e-08
# Epoch 4/100, Batch 900/1338, Batch Loss: 2.6077021431092362e-08
# Epoch 4/100, Batch 1000/1338, Batch Loss: 6.332989954671575e-08
# Epoch 4/100, Batch 1100/1338, Batch Loss: 3.725290076417309e-09
# Epoch 4/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 4/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 4/100, Average Loss: 0.0011060339126492916
# Changed rows in epoch 3: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6083,  0.4359, -0.4634,  ..., -0.3889,  1.1671,  0.0654],
#         [ 0.8773, -0.0406, -0.2163,  ...,  1.3965,  0.0702,  0.1356],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4579],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.60544011628172e-05
# Epoch 5/100, Batch 100/1338, Batch Loss: 9.31321650909922e-08
# Epoch 5/100, Batch 200/1338, Batch Loss: 1.6018722703847743e-07
# Epoch 5/100, Batch 300/1338, Batch Loss: 2.8684695507763536e-07
# Epoch 5/100, Batch 400/1338, Batch Loss: 3.352760558072987e-08
# Epoch 5/100, Batch 500/1338, Batch Loss: 3.725289587919178e-08
# Epoch 5/100, Batch 600/1338, Batch Loss: 3.725290076417309e-09
# Epoch 5/100, Batch 700/1338, Batch Loss: 2.607702498380604e-08
# Epoch 5/100, Batch 800/1338, Batch Loss: 3.725290076417309e-09
# Epoch 5/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 5/100, Batch 1000/1338, Batch Loss: 7.450580152834618e-09
# Epoch 5/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 5/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 5/100, Batch 1300/1338, Batch Loss: 6.705469104417716e-07
# Epoch 5/100, Average Loss: 1.7635780088496357e-06
# Changed rows in epoch 4: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6084,  0.4359, -0.4634,  ..., -0.3889,  1.1671,  0.0654],
#         [ 0.8773, -0.0407, -0.2165,  ...,  1.3967,  0.0702,  0.1355],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4579],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.0929778562441447e-05
# Epoch 6/100, Batch 100/1338, Batch Loss: 3.725290076417309e-09
# Epoch 6/100, Batch 200/1338, Batch Loss: 7.450577754752885e-08
# Epoch 6/100, Batch 300/1338, Batch Loss: 1.862644793959589e-08
# Epoch 6/100, Batch 400/1338, Batch Loss: 5.960460924825384e-08
# Epoch 6/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 6/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 6/100, Batch 700/1338, Batch Loss: 3.725290076417309e-09
# Epoch 6/100, Batch 800/1338, Batch Loss: 3.725290076417309e-09
# Epoch 6/100, Batch 900/1338, Batch Loss: 2.607702676016288e-08
# Epoch 6/100, Batch 1000/1338, Batch Loss: 2.2351734685344127e-08
# Epoch 6/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 6/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 6/100, Batch 1300/1338, Batch Loss: 3.7252888773764425e-08
# Epoch 6/100, Average Loss: 7.016572186904266e-07
# Changed rows in epoch 5: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6084,  0.4354, -0.4640,  ..., -0.3883,  1.1669,  0.0650],
#         [ 0.8773, -0.0406, -0.2165,  ...,  1.3966,  0.0703,  0.1355],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4579],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 8.920729623600465e-06
# Epoch 7/100, Batch 100/1338, Batch Loss: 1.4528606584462977e-07
# Epoch 7/100, Batch 200/1338, Batch Loss: 7.450578465295621e-08
# Epoch 7/100, Batch 300/1338, Batch Loss: 3.725290076417309e-09
# Epoch 7/100, Batch 400/1338, Batch Loss: 7.450580152834618e-09
# Epoch 7/100, Batch 500/1338, Batch Loss: 2.2351736461700966e-08
# Epoch 7/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 7/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 7/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 7/100, Batch 900/1338, Batch Loss: 3.7252888773764425e-08
# Epoch 7/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 7/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 7/100, Batch 1200/1338, Batch Loss: 4.097803980585013e-07
# Epoch 7/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 7/100, Average Loss: 3.9092909231786686e-07
# Changed rows in epoch 6: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6085,  0.4349, -0.4652,  ..., -0.3875,  1.1668,  0.0645],
#         [ 0.8773, -0.0408, -0.2168,  ...,  1.3968,  0.0701,  0.1353],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4579],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 7.164497330143978e-06
# Epoch 8/100, Batch 100/1338, Batch Loss: 3.7252892326478104e-08
# Epoch 8/100, Batch 200/1338, Batch Loss: 2.607702676016288e-08
# Epoch 8/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 8/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 8/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 8/100, Batch 600/1338, Batch Loss: 2.7939566393797577e-07
# Epoch 8/100, Batch 700/1338, Batch Loss: 2.1234082225873863e-07
# Epoch 8/100, Batch 800/1338, Batch Loss: 7.450580152834618e-09
# Epoch 8/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 8/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 8/100, Batch 1100/1338, Batch Loss: 1.862644793959589e-08
# Epoch 8/100, Batch 1200/1338, Batch Loss: 1.1175869119028903e-08
# Epoch 8/100, Batch 1300/1338, Batch Loss: 9.313219351270163e-08
# Epoch 8/100, Average Loss: 1.8766919032715722e-07
# Changed rows in epoch 7: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6085,  0.4355, -0.4645,  ..., -0.3877,  1.1670,  0.0648],
#         [ 0.8773, -0.0403, -0.2161,  ...,  1.3964,  0.0707,  0.1357],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4579],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 5.894471003268601e-06
# Epoch 9/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 9/100, Batch 200/1338, Batch Loss: 2.6077021431092362e-08
# Epoch 9/100, Batch 300/1338, Batch Loss: 3.725290076417309e-09
# Epoch 9/100, Batch 400/1338, Batch Loss: 3.725290076417309e-09
# Epoch 9/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 9/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 9/100, Batch 700/1338, Batch Loss: 3.725290076417309e-09
# Epoch 9/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 9/100, Batch 900/1338, Batch Loss: 1.1175870007207322e-08
# Epoch 9/100, Batch 1000/1338, Batch Loss: 8.568160581035045e-08
# Epoch 9/100, Batch 1100/1338, Batch Loss: 1.0430801467009587e-07
# Epoch 9/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 9/100, Batch 1300/1338, Batch Loss: 7.4505797087454084e-09
# Epoch 9/100, Average Loss: 2.3500801205836353e-07
# Changed rows in epoch 8: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6085,  0.4343, -0.4667,  ..., -0.3864,  1.1667,  0.0639],
#         [ 0.8773, -0.0401, -0.2157,  ...,  1.3963,  0.0708,  0.1358],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 4.59652904756247e-06
# Epoch 10/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 10/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 10/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 10/100, Batch 400/1338, Batch Loss: 3.725290076417309e-09
# Epoch 10/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 10/100, Batch 600/1338, Batch Loss: 7.4505797087454084e-09
# Epoch 10/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 10/100, Batch 800/1338, Batch Loss: 5.58793225025056e-08
# Epoch 10/100, Batch 900/1338, Batch Loss: 1.4901157641133977e-08
# Epoch 10/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 10/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 10/100, Batch 1200/1338, Batch Loss: 7.450580152834618e-09
# Epoch 10/100, Batch 1300/1338, Batch Loss: 1.862644971595273e-08
# Epoch 10/100, Average Loss: 3.092435669952868e-08
# Changed rows in epoch 9: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6086,  0.4339, -0.4673,  ..., -0.3856,  1.1665,  0.0634],
#         [ 0.8773, -0.0399, -0.2154,  ...,  1.3960,  0.0710,  0.1360],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 4.0191164582351986e-06
# Epoch 11/100, Batch 100/1338, Batch Loss: 7.4505797087454084e-09
# Epoch 11/100, Batch 200/1338, Batch Loss: 3.725290076417309e-09
# Epoch 11/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 11/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 11/100, Batch 500/1338, Batch Loss: 3.725290076417309e-09
# Epoch 11/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 11/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 11/100, Batch 800/1338, Batch Loss: 7.450580152834618e-09
# Epoch 11/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 11/100, Batch 1000/1338, Batch Loss: 4.4703465817974575e-08
# Epoch 11/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 11/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 11/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 11/100, Average Loss: 2.7586133384248727e-08
# Changed rows in epoch 10: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6087,  0.4334, -0.4687,  ..., -0.3846,  1.1662,  0.0625],
#         [ 0.8773, -0.0400, -0.2156,  ...,  1.3960,  0.0710,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7577, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 3.147834935498158e-06
# Epoch 12/100, Batch 100/1338, Batch Loss: 3.725290076417309e-09
# Epoch 12/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 12/100, Batch 300/1338, Batch Loss: 3.725290076417309e-09
# Epoch 12/100, Batch 400/1338, Batch Loss: 6.332987112500632e-08
# Epoch 12/100, Batch 500/1338, Batch Loss: 3.725290076417309e-09
# Epoch 12/100, Batch 600/1338, Batch Loss: 7.078045172193015e-08
# Epoch 12/100, Batch 700/1338, Batch Loss: 3.725290076417309e-09
# Epoch 12/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 12/100, Batch 900/1338, Batch Loss: 3.352760558072987e-08
# Epoch 12/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 12/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 12/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 12/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 12/100, Average Loss: 3.6000843129555204e-08
# Changed rows in epoch 11: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6118,  0.4206, -0.4931,  ..., -0.3668,  1.1634,  0.0470],
#         [ 0.8773, -0.0407, -0.2164,  ...,  1.3972,  0.0703,  0.1353],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.0365857357636702e-06
# Epoch 13/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 200/1338, Batch Loss: 1.4901157641133977e-08
# Epoch 13/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 1000/1338, Batch Loss: 3.725290076417309e-09
# Epoch 13/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 13/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 13/100, Average Loss: 7.603193723511013e-09
# Changed rows in epoch 12: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6122,  0.4204, -0.4957,  ..., -0.3660,  1.1636,  0.0465],
#         [ 0.8773, -0.0408, -0.2167,  ...,  1.3972,  0.0704,  0.1353],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.523360938708862e-06
# Epoch 14/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 800/1338, Batch Loss: 2.7194499807592365e-07
# Epoch 14/100, Batch 900/1338, Batch Loss: 4.470345160711986e-08
# Epoch 14/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 14/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 14/100, Average Loss: 3.0208555169040215e-09
# Changed rows in epoch 13: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6121,  0.4207, -0.4953,  ..., -0.3626,  1.1632,  0.0463],
#         [ 0.8774, -0.0402, -0.2140,  ...,  1.3973,  0.0701,  0.1360],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3427,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.2500820832854012e-06
# Epoch 15/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 1100/1338, Batch Loss: 4.693830533142318e-07
# Epoch 15/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 15/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 15/100, Average Loss: 1.3837540492285974e-09
# Changed rows in epoch 14: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6121,  0.4208, -0.4954,  ..., -0.3617,  1.1631,  0.0462],
#         [ 0.8774, -0.0402, -0.2142,  ...,  1.3973,  0.0701,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.0136283040888354e-06
# Epoch 16/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 16/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 16/100, Average Loss: 4.6496503956467245e-10
# Changed rows in epoch 15: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6121,  0.4206, -0.4957,  ..., -0.3612,  1.1630,  0.0460],
#         [ 0.8774, -0.0402, -0.2141,  ...,  1.3973,  0.0701,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 8.832286887638929e-07
# Epoch 17/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 17/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 17/100, Average Loss: 3.8979099718752213e-10
# Changed rows in epoch 16: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6120,  0.4204, -0.4961,  ..., -0.3605,  1.1628,  0.0458],
#         [ 0.8774, -0.0402, -0.2140,  ...,  1.3973,  0.0700,  0.1360],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 7.468651165017567e-07
# Epoch 18/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 18/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 18/100, Average Loss: 1.5591643123576967e-10
# Changed rows in epoch 17: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6119,  0.4202, -0.4963,  ..., -0.3596,  1.1624,  0.0455],
#         [ 0.8774, -0.0403, -0.2142,  ...,  1.3973,  0.0700,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 6.148658091357599e-07
# Epoch 19/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 19/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 19/100, Average Loss: 9.466355551950938e-11
# Changed rows in epoch 18: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6119,  0.4204, -0.4961,  ..., -0.3594,  1.1623,  0.0455],
#         [ 0.8773, -0.0404, -0.2143,  ...,  1.3973,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 5.168335337657481e-07
# Epoch 20/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 20/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 20/100, Average Loss: 2.784222711210364e-11
# Changed rows in epoch 19: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6118,  0.4204, -0.4960,  ..., -0.3592,  1.1623,  0.0455],
#         [ 0.8773, -0.0403, -0.2143,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2046, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 4.2833048307026427e-07
# Epoch 21/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 21/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 21/100, Average Loss: 2.505800466641747e-11
# Changed rows in epoch 20: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6117,  0.4203, -0.4961,  ..., -0.3591,  1.1622,  0.0455],
#         [ 0.8773, -0.0403, -0.2143,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 3.8025519946434843e-07
# Epoch 22/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 22/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 22/100, Average Loss: 2.2273778237868426e-11
# Changed rows in epoch 21: tensor([   1,    2,    3,  ..., 1670, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6116,  0.4203, -0.4961,  ..., -0.3590,  1.1622,  0.0455],
#         [ 0.8773, -0.0403, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 3.1519382901024076e-07
# Epoch 23/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 23/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 23/100, Average Loss: 5.5684452232775844e-12
# Changed rows in epoch 22: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6114,  0.4204, -0.4961,  ..., -0.3589,  1.1622,  0.0455],
#         [ 0.8773, -0.0403, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 3.0923392235611876e-07
# Epoch 24/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 24/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 24/100, Average Loss: 5.5684452232775844e-12
# Changed rows in epoch 23: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6114,  0.4204, -0.4960,  ..., -0.3589,  1.1622,  0.0455],
#         [ 0.8773, -0.0403, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.985060321710383e-07
# Epoch 25/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 25/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 25/100, Average Loss: 5.5684452232775844e-12
# Changed rows in epoch 24: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6110,  0.4204, -0.4960,  ..., -0.3588,  1.1621,  0.0455],
#         [ 0.8773, -0.0403, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.1129143230306605e-07
# Epoch 26/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 26/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 26/100, Average Loss: 0.0
# Changed rows in epoch 25: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6110,  0.4204, -0.4960,  ..., -0.3588,  1.1621,  0.0455],
#         [ 0.8773, -0.0403, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.355289567882816e-07
# Epoch 27/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 27/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 27/100, Average Loss: 0.0
# Changed rows in epoch 26: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6109,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0403, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 3.13703737144048e-07
# Epoch 28/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 28/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 28/100, Average Loss: 0.0
# Changed rows in epoch 27: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6107,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0403, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 5.092818173579872e-07
# Epoch 29/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 29/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 29/100, Average Loss: 5.5684452232775844e-12
# Changed rows in epoch 28: tensor([   1,    2,    3,  ..., 1664, 1668, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6105,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.5814703753373274e-07
# Epoch 30/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 30/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 30/100, Average Loss: 0.0
# Changed rows in epoch 29: tensor([   1,    2,    3,  ..., 1668, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6105,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.785108785649451e-07
# Epoch 31/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 31/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 31/100, Average Loss: 0.0
# Changed rows in epoch 30: tensor([   1,    2,    3,  ..., 1670, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6104,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.0801341937234005e-07
# Epoch 32/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 32/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 32/100, Average Loss: 0.0
# Changed rows in epoch 31: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6104,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.795335846409823e-07
# Epoch 33/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 33/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 33/100, Average Loss: 3.1819688886758992e-12
# Changed rows in epoch 32: tensor([   1,    2,    3,  ..., 1670, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6102,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2144,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 4.226688179187477e-07
# Epoch 34/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 34/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 34/100, Average Loss: 0.0
# Changed rows in epoch 33: tensor([   1,    2,    3,  ..., 1664, 1668, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6102,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2145,  ...,  1.3974,  0.0700,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.7205408463875453e-07
# Epoch 35/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 35/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 35/100, Average Loss: 0.0
# Changed rows in epoch 34: tensor([   1,    2,    3,  ..., 1668, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6100,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2145,  ...,  1.3974,  0.0700,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.053313801297918e-07
# Epoch 36/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 36/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 36/100, Average Loss: 0.0
# Changed rows in epoch 35: tensor([   1,    2,    3,  ..., 1668, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6099,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2145,  ...,  1.3974,  0.0700,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.751629896617184e-07
# Epoch 37/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 37/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 37/100, Average Loss: 0.0
# Changed rows in epoch 36: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6099,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0455],
#         [ 0.8773, -0.0404, -0.2145,  ...,  1.3974,  0.0700,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 4.4015061575919387e-07
# Epoch 38/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 38/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 38/100, Average Loss: 2.784222777591412e-12
# Changed rows in epoch 37: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6097,  0.4204, -0.4960,  ..., -0.3587,  1.1621,  0.0454],
#         [ 0.8773, -0.0404, -0.2145,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 2.878774830605835e-07
# Epoch 39/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 39/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 39/100, Average Loss: 3.1819688886758992e-12
# Changed rows in epoch 38: tensor([   1,    2,    3,  ..., 1675, 1677, 1681])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6096,  0.4204, -0.4960,  ..., -0.3586,  1.1621,  0.0454],
#         [ 0.8772, -0.0404, -0.2145,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 3.7002428143750876e-07
# Epoch 40/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 40/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 40/100, Average Loss: 0.0
# Changed rows in epoch 39: tensor([   1,    2,    3,  ..., 1664, 1668, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6096,  0.4204, -0.4960,  ..., -0.3586,  1.1621,  0.0454],
#         [ 0.8772, -0.0404, -0.2145,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.5814698902734866e-07
# Epoch 41/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 41/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 41/100, Average Loss: 0.0
# Changed rows in epoch 40: tensor([   1,    2,    3,  ..., 1670, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6096,  0.4204, -0.4960,  ..., -0.3586,  1.1621,  0.0454],
#         [ 0.8772, -0.0404, -0.2145,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.7265003407374024e-07
# Epoch 42/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 300/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 400/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 500/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 600/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 700/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 800/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 900/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 1000/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 1100/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 1200/1338, Batch Loss: 0.0
# Epoch 42/100, Batch 1300/1338, Batch Loss: 0.0
# Epoch 42/100, Average Loss: 0.0
# Changed rows in epoch 41: tensor([   1,    2,    3,  ..., 1670, 1675, 1677])
# Parameter containing:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 0.6095,  0.4204, -0.4960,  ..., -0.3586,  1.1621,  0.0454],
#         [ 0.8772, -0.0404, -0.2145,  ...,  1.3974,  0.0699,  0.1359],
#         ...,
#         [ 0.6299,  0.9163, -0.4314,  ...,  1.5181, -0.2542, -0.1127],
#         [ 1.7576, -0.2047, -0.3428,  ...,  0.1121,  0.9949, -1.4580],
#         [ 0.2967,  0.8782, -0.9808,  ...,  0.5055,  0.7454,  0.2543]],
#        requires_grad=True)
# Test Loss: 1.89835081982892e-07
# Epoch 43/100, Batch 100/1338, Batch Loss: 0.0
# Epoch 43/100, Batch 200/1338, Batch Loss: 0.0
# Epoch 43/100, Batch 300/1338, Batch Loss: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-382107667079> in <cell line: 91>()
#     100         output = model(windows, watched_genres, user_feat, watched_movie_age)
#     101         loss = model.loss(output, labels, disliked_movies)
# --> 102         loss.backward()
#     103         optimizer.step()
#     104         total_loss += loss.item()
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     485                 inputs=inputs,
#     486             )
# --> 487         torch.autograd.backward(
#     488             self, gradient, retain_graph, create_graph, inputs=inputs
#     489         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     198     # some Python versions print out the first line of a multi-line function
#     199     # calls in the traceback and some print out the last line
# --> 200     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# Initialize DataLoader for testing
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# Initialize variables for mAP
mAP_N = 0
rmAP_N = 0
display_freq = 100
top_N_size = 100  # Specify the maximum size for top_N

# Iterate over all batches in the test set
for  batch_num, ( user_ids, windows, watched_genres, watched_movie_age, user_feat, labels, labels_like, disliked_movies) in enumerate(test_dataloader, 1):
    user_ids, windows, watched_genres, watched_movie_age, user_feat, labels, disliked_movies = user_ids.to(device), windows.to(device), watched_genres.to(device), watched_movie_age.to(device), user_feat.to(device),  labels.to(device),disliked_movies.to(device)

    windows = windows.repeat(batch_size, 1)
    watched_genre = watched_genres.repeat(batch_size, 1)
    user_feature = user_feat.repeat(batch_size, 1)
    watched_movie_age = watched_movie_age.repeat(batch_size, 1)


    # Get the user embedding from the model
    user_embedding = model(windows, watched_genre, user_feature, watched_movie_age)

    # Compute scores for all movies
    all_movie_scores = torch.matmul(user_embedding, model.movie_embedding.weight.T)

    # Sort the movie IDs by their scores in descending order
    sorted_movie_ids = all_movie_scores.argsort(descending=True)

    # Prepare liked movie data for this batch
    user_id = user_ids.item()  # get the user_id as a single number, not a list
    liked_movies = expanded_df[expanded_df['userId'] == user_id]['liked_movies'].values[0]

    for top_N in range(10, top_N_size+1):
        # Get the top N movie IDs from the sorted list
        top_movie_ids = sorted_movie_ids[0, :top_N].tolist()

        # Find the true positive movies
        true_positive = [movie_id for movie_id in top_movie_ids if movie_id in liked_movies]
        # Total positive cases
        positive = liked_movies

        # Select random movies
        random_movie_ids = torch.randint(len(model.movie_embedding.weight), (top_N,)).tolist()
        random_positive = [movie_id for movie_id in random_movie_ids if movie_id in liked_movies]

        if top_N % display_freq == 0 or top_N == 1:
            print(f'top N  = {top_N} -------------------\n')
            print(f'model  = Rank {top_N} Recall    : {len(true_positive)/len(positive)} ({len(true_positive)}/{len(positive)})')
            print(f'model  = Rank {top_N} Precision : {len(true_positive)/top_N} ({len(true_positive)}/{top_N})\n')
            print(f'random = Rank {top_N} Recall    : {len(random_positive)/len(positive)} ({len(random_positive)}/{len(positive)})')
            print(f'random = Rank {top_N} Precision : {len(random_positive)/top_N} ({len(random_positive)}/{top_N})\n')

        # Add to the mAP
        mAP_N += len(true_positive) / top_N
        rmAP_N += len(random_positive) / top_N

print(f'mAP@{top_N_size} = {mAP_N/(top_N_size * len(test_dataset))}')
print(f'rmAP@{top_N_size} = {rmAP_N/(top_N_size * len(test_dataset))}')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# model  = Rank 100 Recall    : 0.11258278145695365 (17/151)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.039735099337748346 (6/151)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09933774834437085 (15/151)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.046357615894039736 (7/151)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08609271523178808 (13/151)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.052980132450331126 (8/151)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08609271523178808 (13/151)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.059602649006622516 (9/151)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.0728476821192053 (11/151)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09933774834437085 (15/151)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.06622516556291391 (10/151)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09933774834437085 (15/151)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.046357615894039736 (7/151)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0859375 (11/128)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.0703125 (9/128)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0859375 (11/128)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.109375 (14/128)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09375 (12/128)
# model  = Rank 100 Precision : 0.12 (12/100)
#
# random = Rank 100 Recall    : 0.03125 (4/128)
# random = Rank 100 Precision : 0.04 (4/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0859375 (11/128)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.03125 (4/128)
# random = Rank 100 Precision : 0.04 (4/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0859375 (11/128)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.0390625 (5/128)
# random = Rank 100 Precision : 0.05 (5/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0859375 (11/128)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.0546875 (7/128)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.05357142857142857 (27/504)
# random = Rank 100 Precision : 0.27 (27/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.07142857142857142 (36/504)
# random = Rank 100 Precision : 0.36 (36/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07341269841269842 (37/504)
# model  = Rank 100 Precision : 0.37 (37/100)
#
# random = Rank 100 Recall    : 0.047619047619047616 (24/504)
# random = Rank 100 Precision : 0.24 (24/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.07142857142857142 (36/504)
# random = Rank 100 Precision : 0.36 (36/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.03373015873015873 (17/504)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.0496031746031746 (25/504)
# random = Rank 100 Precision : 0.25 (25/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.06746031746031746 (34/504)
# random = Rank 100 Precision : 0.34 (34/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.05952380952380952 (30/504)
# random = Rank 100 Precision : 0.3 (30/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.03968253968253968 (20/504)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.06349206349206349 (32/504)
# random = Rank 100 Precision : 0.32 (32/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07341269841269842 (37/504)
# model  = Rank 100 Precision : 0.37 (37/100)
#
# random = Rank 100 Recall    : 0.05357142857142857 (27/504)
# random = Rank 100 Precision : 0.27 (27/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.06547619047619048 (33/504)
# random = Rank 100 Precision : 0.33 (33/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.05952380952380952 (30/504)
# random = Rank 100 Precision : 0.3 (30/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.061507936507936505 (31/504)
# random = Rank 100 Precision : 0.31 (31/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.06349206349206349 (32/504)
# random = Rank 100 Precision : 0.32 (32/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.057539682539682536 (29/504)
# random = Rank 100 Precision : 0.29 (29/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.06547619047619048 (33/504)
# random = Rank 100 Precision : 0.33 (33/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07341269841269842 (37/504)
# model  = Rank 100 Precision : 0.37 (37/100)
#
# random = Rank 100 Recall    : 0.06349206349206349 (32/504)
# random = Rank 100 Precision : 0.32 (32/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.08134920634920635 (41/504)
# random = Rank 100 Precision : 0.41 (41/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.07142857142857142 (36/504)
# random = Rank 100 Precision : 0.36 (36/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.061507936507936505 (31/504)
# random = Rank 100 Precision : 0.31 (31/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07341269841269842 (37/504)
# model  = Rank 100 Precision : 0.37 (37/100)
#
# random = Rank 100 Recall    : 0.06349206349206349 (32/504)
# random = Rank 100 Precision : 0.32 (32/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07142857142857142 (36/504)
# model  = Rank 100 Precision : 0.36 (36/100)
#
# random = Rank 100 Recall    : 0.03968253968253968 (20/504)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07341269841269842 (37/504)
# model  = Rank 100 Precision : 0.37 (37/100)
#
# random = Rank 100 Recall    : 0.07142857142857142 (36/504)
# random = Rank 100 Precision : 0.36 (36/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07341269841269842 (37/504)
# model  = Rank 100 Precision : 0.37 (37/100)
#
# random = Rank 100 Recall    : 0.051587301587301584 (26/504)
# random = Rank 100 Precision : 0.26 (26/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.1 (18/180)
# model  = Rank 100 Precision : 0.18 (18/100)
#
# random = Rank 100 Recall    : 0.05555555555555555 (10/180)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09444444444444444 (17/180)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.08888888888888889 (16/180)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09444444444444444 (17/180)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.06111111111111111 (11/180)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09444444444444444 (17/180)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.06111111111111111 (11/180)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10555555555555556 (19/180)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.07222222222222222 (13/180)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09444444444444444 (17/180)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.07222222222222222 (13/180)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09444444444444444 (17/180)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.03888888888888889 (7/180)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.1111111111111111 (20/180)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.07777777777777778 (14/180)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.1111111111111111 (20/180)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.044444444444444446 (8/180)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10071942446043165 (14/139)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.06474820143884892 (9/139)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10071942446043165 (14/139)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.04316546762589928 (6/139)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10071942446043165 (14/139)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.02877697841726619 (4/139)
# random = Rank 100 Precision : 0.04 (4/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10071942446043165 (14/139)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.04316546762589928 (6/139)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.1079136690647482 (15/139)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.04316546762589928 (6/139)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10071942446043165 (14/139)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.06474820143884892 (9/139)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.1079136690647482 (15/139)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.050359712230215826 (7/139)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0784313725490196 (12/153)
# model  = Rank 100 Precision : 0.12 (12/100)
#
# random = Rank 100 Recall    : 0.058823529411764705 (9/153)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0784313725490196 (12/153)
# model  = Rank 100 Precision : 0.12 (12/100)
#
# random = Rank 100 Recall    : 0.06535947712418301 (10/153)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0915032679738562 (14/153)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.0718954248366013 (11/153)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0784313725490196 (12/153)
# model  = Rank 100 Precision : 0.12 (12/100)
#
# random = Rank 100 Recall    : 0.032679738562091505 (5/153)
# random = Rank 100 Precision : 0.05 (5/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08496732026143791 (13/153)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.11764705882352941 (18/153)
# random = Rank 100 Precision : 0.18 (18/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0915032679738562 (14/153)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.0457516339869281 (7/153)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0784313725490196 (12/153)
# model  = Rank 100 Precision : 0.12 (12/100)
#
# random = Rank 100 Recall    : 0.0196078431372549 (3/153)
# random = Rank 100 Precision : 0.03 (3/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.0784313725490196 (12/153)
# model  = Rank 100 Precision : 0.12 (12/100)
#
# random = Rank 100 Recall    : 0.058823529411764705 (9/153)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.136 (17/125)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.08 (10/125)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.144 (18/125)
# model  = Rank 100 Precision : 0.18 (18/100)
#
# random = Rank 100 Recall    : 0.056 (7/125)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.136 (17/125)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.064 (8/125)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.136 (17/125)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.072 (9/125)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.136 (17/125)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.056 (7/125)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.144 (18/125)
# model  = Rank 100 Precision : 0.18 (18/100)
#
# random = Rank 100 Recall    : 0.056 (7/125)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.1 (23/230)
# random = Rank 100 Precision : 0.23 (23/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.05652173913043478 (13/230)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08695652173913043 (20/230)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.05217391304347826 (12/230)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.06086956521739131 (14/230)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.06086956521739131 (14/230)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09130434782608696 (21/230)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.030434782608695653 (7/230)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.0782608695652174 (18/230)
# random = Rank 100 Precision : 0.18 (18/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.06086956521739131 (14/230)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.043478260869565216 (10/230)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08260869565217391 (19/230)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.06521739130434782 (15/230)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08695652173913043 (20/230)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.06956521739130435 (16/230)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.06209150326797386 (19/306)
# random = Rank 100 Precision : 0.19 (19/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10784313725490197 (33/306)
# model  = Rank 100 Precision : 0.33 (33/100)
#
# random = Rank 100 Recall    : 0.042483660130718956 (13/306)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.06535947712418301 (20/306)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.05228758169934641 (16/306)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.03594771241830065 (11/306)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.0392156862745098 (12/306)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09803921568627451 (30/306)
# model  = Rank 100 Precision : 0.3 (30/100)
#
# random = Rank 100 Recall    : 0.0457516339869281 (14/306)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.049019607843137254 (15/306)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.0392156862745098 (12/306)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.05555555555555555 (17/306)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10457516339869281 (32/306)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.06209150326797386 (19/306)
# random = Rank 100 Precision : 0.19 (19/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.05555555555555555 (17/306)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10784313725490197 (33/306)
# model  = Rank 100 Precision : 0.33 (33/100)
#
# random = Rank 100 Recall    : 0.042483660130718956 (13/306)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10784313725490197 (33/306)
# model  = Rank 100 Precision : 0.33 (33/100)
#
# random = Rank 100 Recall    : 0.049019607843137254 (15/306)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10130718954248366 (31/306)
# model  = Rank 100 Precision : 0.31 (31/100)
#
# random = Rank 100 Recall    : 0.06535947712418301 (20/306)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.14285714285714285 (16/112)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.008928571428571428 (1/112)
# random = Rank 100 Precision : 0.01 (1/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.13392857142857142 (15/112)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.017857142857142856 (2/112)
# random = Rank 100 Precision : 0.02 (2/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.13392857142857142 (15/112)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.044642857142857144 (5/112)
# random = Rank 100 Precision : 0.05 (5/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.14285714285714285 (16/112)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.09821428571428571 (11/112)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.13392857142857142 (15/112)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.0625 (7/112)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.13392857142857142 (15/112)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.08035714285714286 (9/112)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11627906976744186 (15/129)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.0 (0/129)
# random = Rank 100 Precision : 0.0 (0/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10852713178294573 (14/129)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.05426356589147287 (7/129)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11627906976744186 (15/129)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.07751937984496124 (10/129)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10852713178294573 (14/129)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.10077519379844961 (13/129)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10852713178294573 (14/129)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.08527131782945736 (11/129)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10077519379844961 (13/129)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.06201550387596899 (8/129)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.07614213197969544 (15/197)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.04060913705583756 (8/197)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.05583756345177665 (11/197)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.09137055837563451 (18/197)
# random = Rank 100 Precision : 0.18 (18/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.05583756345177665 (11/197)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.08121827411167512 (16/197)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.05583756345177665 (11/197)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.04568527918781726 (9/197)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.08121827411167512 (16/197)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08121827411167512 (16/197)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.06091370558375635 (12/197)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.058333333333333334 (7/120)
# model  = Rank 100 Precision : 0.07 (7/100)
#
# random = Rank 100 Recall    : 0.08333333333333333 (10/120)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06666666666666667 (8/120)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.058333333333333334 (7/120)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.075 (9/120)
# model  = Rank 100 Precision : 0.09 (9/100)
#
# random = Rank 100 Recall    : 0.016666666666666666 (2/120)
# random = Rank 100 Precision : 0.02 (2/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.058333333333333334 (7/120)
# model  = Rank 100 Precision : 0.07 (7/100)
#
# random = Rank 100 Recall    : 0.05 (6/120)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.058333333333333334 (7/120)
# model  = Rank 100 Precision : 0.07 (7/100)
#
# random = Rank 100 Recall    : 0.03333333333333333 (4/120)
# random = Rank 100 Precision : 0.04 (4/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.058333333333333334 (7/120)
# model  = Rank 100 Precision : 0.07 (7/100)
#
# random = Rank 100 Recall    : 0.06666666666666667 (8/120)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.105 (21/200)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.045 (9/200)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11 (22/200)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.055 (11/200)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11 (22/200)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.045 (9/200)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.115 (23/200)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.075 (15/200)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.105 (21/200)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.045 (9/200)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11 (22/200)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.035 (7/200)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11 (22/200)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.065 (13/200)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11 (22/200)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.075 (15/200)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11 (22/200)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.04 (8/200)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11 (22/200)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.05 (10/200)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.052980132450331126 (8/151)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.06622516556291391 (10/151)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.06622516556291391 (10/151)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.033112582781456956 (5/151)
# random = Rank 100 Precision : 0.05 (5/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.0728476821192053 (11/151)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.052980132450331126 (8/151)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.0728476821192053 (11/151)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09271523178807947 (14/151)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.0728476821192053 (11/151)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07692307692307693 (10/130)
# model  = Rank 100 Precision : 0.1 (10/100)
#
# random = Rank 100 Recall    : 0.09230769230769231 (12/130)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07692307692307693 (10/130)
# model  = Rank 100 Precision : 0.1 (10/100)
#
# random = Rank 100 Recall    : 0.046153846153846156 (6/130)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07692307692307693 (10/130)
# model  = Rank 100 Precision : 0.1 (10/100)
#
# random = Rank 100 Recall    : 0.06153846153846154 (8/130)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07692307692307693 (10/130)
# model  = Rank 100 Precision : 0.1 (10/100)
#
# random = Rank 100 Recall    : 0.05384615384615385 (7/130)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08461538461538462 (11/130)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.05384615384615385 (7/130)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07692307692307693 (10/130)
# model  = Rank 100 Precision : 0.1 (10/100)
#
# random = Rank 100 Recall    : 0.046153846153846156 (6/130)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09243697478991597 (22/238)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.046218487394957986 (11/238)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.046218487394957986 (11/238)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.06302521008403361 (15/238)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09243697478991597 (22/238)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.046218487394957986 (11/238)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.037815126050420166 (9/238)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.0546218487394958 (13/238)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.06302521008403361 (15/238)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.07563025210084033 (18/238)
# random = Rank 100 Precision : 0.18 (18/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.058823529411764705 (14/238)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.06302521008403361 (15/238)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09663865546218488 (23/238)
# model  = Rank 100 Precision : 0.23 (23/100)
#
# random = Rank 100 Recall    : 0.07142857142857142 (17/238)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09243697478991597 (22/238)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.046218487394957986 (11/238)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.0457516339869281 (7/153)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.0457516339869281 (7/153)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.058823529411764705 (9/153)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.0457516339869281 (7/153)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.0784313725490196 (12/153)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.06535947712418301 (10/153)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.0457516339869281 (7/153)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.05228758169934641 (8/153)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.0718954248366013 (11/153)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06976744186046512 (15/215)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.06976744186046512 (15/215)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.06511627906976744 (14/215)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.07906976744186046 (17/215)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06976744186046512 (15/215)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.07441860465116279 (16/215)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.05581395348837209 (12/215)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.10232558139534884 (22/215)
# random = Rank 100 Precision : 0.22 (22/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06976744186046512 (15/215)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.06511627906976744 (14/215)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.046511627906976744 (10/215)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.07441860465116279 (16/215)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.06046511627906977 (13/215)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07441860465116279 (16/215)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.046511627906976744 (10/215)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.04669260700389105 (12/257)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.058365758754863814 (15/257)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.054474708171206226 (14/257)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08171206225680934 (21/257)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.042801556420233464 (11/257)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08560311284046693 (22/257)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.06614785992217899 (17/257)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.06614785992217899 (17/257)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.07782101167315175 (20/257)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08171206225680934 (21/257)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.08171206225680934 (21/257)
# random = Rank 100 Precision : 0.21 (21/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.07003891050583658 (18/257)
# random = Rank 100 Precision : 0.18 (18/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.07392996108949416 (19/257)
# random = Rank 100 Precision : 0.19 (19/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.04669260700389105 (12/257)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08171206225680934 (21/257)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.08171206225680934 (21/257)
# random = Rank 100 Precision : 0.21 (21/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07782101167315175 (20/257)
# model  = Rank 100 Precision : 0.2 (20/100)
#
# random = Rank 100 Recall    : 0.07003891050583658 (18/257)
# random = Rank 100 Precision : 0.18 (18/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09454545454545454 (26/275)
# model  = Rank 100 Precision : 0.26 (26/100)
#
# random = Rank 100 Recall    : 0.04727272727272727 (13/275)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09818181818181818 (27/275)
# model  = Rank 100 Precision : 0.27 (27/100)
#
# random = Rank 100 Recall    : 0.04727272727272727 (13/275)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09454545454545454 (26/275)
# model  = Rank 100 Precision : 0.26 (26/100)
#
# random = Rank 100 Recall    : 0.05454545454545454 (15/275)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09454545454545454 (26/275)
# model  = Rank 100 Precision : 0.26 (26/100)
#
# random = Rank 100 Recall    : 0.07272727272727272 (20/275)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09454545454545454 (26/275)
# model  = Rank 100 Precision : 0.26 (26/100)
#
# random = Rank 100 Recall    : 0.05090909090909091 (14/275)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09090909090909091 (25/275)
# model  = Rank 100 Precision : 0.25 (25/100)
#
# random = Rank 100 Recall    : 0.05454545454545454 (15/275)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09818181818181818 (27/275)
# model  = Rank 100 Precision : 0.27 (27/100)
#
# random = Rank 100 Recall    : 0.05090909090909091 (14/275)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09818181818181818 (27/275)
# model  = Rank 100 Precision : 0.27 (27/100)
#
# random = Rank 100 Recall    : 0.04727272727272727 (13/275)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09818181818181818 (27/275)
# model  = Rank 100 Precision : 0.27 (27/100)
#
# random = Rank 100 Recall    : 0.08727272727272728 (24/275)
# random = Rank 100 Precision : 0.24 (24/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08727272727272728 (24/275)
# model  = Rank 100 Precision : 0.24 (24/100)
#
# random = Rank 100 Recall    : 0.05454545454545454 (15/275)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09090909090909091 (25/275)
# model  = Rank 100 Precision : 0.25 (25/100)
#
# random = Rank 100 Recall    : 0.05454545454545454 (15/275)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08727272727272728 (24/275)
# model  = Rank 100 Precision : 0.24 (24/100)
#
# random = Rank 100 Recall    : 0.06181818181818182 (17/275)
# ...
#
# random = Rank 100 Recall    : 0.05405405405405406 (6/111)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07207207207207207 (8/111)
# model  = Rank 100 Precision : 0.08 (8/100)
#
# random = Rank 100 Recall    : 0.05405405405405406 (6/111)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.13333333333333333 (16/120)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.08333333333333333 (10/120)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.125 (15/120)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.075 (9/120)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11666666666666667 (14/120)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.08333333333333333 (10/120)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.125 (15/120)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.06666666666666667 (8/120)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.125 (15/120)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.05 (6/120)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.13333333333333333 (16/120)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.05 (6/120)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.16363636363636364 (18/110)
# model  = Rank 100 Precision : 0.18 (18/100)
#
# random = Rank 100 Recall    : 0.09090909090909091 (10/110)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.16363636363636364 (18/110)
# model  = Rank 100 Precision : 0.18 (18/100)
#
# random = Rank 100 Recall    : 0.06363636363636363 (7/110)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.16363636363636364 (18/110)
# model  = Rank 100 Precision : 0.18 (18/100)
#
# random = Rank 100 Recall    : 0.03636363636363636 (4/110)
# random = Rank 100 Precision : 0.04 (4/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.17272727272727273 (19/110)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.05454545454545454 (6/110)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.17272727272727273 (19/110)
# model  = Rank 100 Precision : 0.19 (19/100)
#
# random = Rank 100 Recall    : 0.08181818181818182 (9/110)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11764705882352941 (32/272)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.05514705882352941 (15/272)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10661764705882353 (29/272)
# model  = Rank 100 Precision : 0.29 (29/100)
#
# random = Rank 100 Recall    : 0.03676470588235294 (10/272)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.1213235294117647 (33/272)
# model  = Rank 100 Precision : 0.33 (33/100)
#
# random = Rank 100 Recall    : 0.07352941176470588 (20/272)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11029411764705882 (30/272)
# model  = Rank 100 Precision : 0.3 (30/100)
#
# random = Rank 100 Recall    : 0.058823529411764705 (16/272)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11764705882352941 (32/272)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.05514705882352941 (15/272)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10661764705882353 (29/272)
# model  = Rank 100 Precision : 0.29 (29/100)
#
# random = Rank 100 Recall    : 0.09191176470588236 (25/272)
# random = Rank 100 Precision : 0.25 (25/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10661764705882353 (29/272)
# model  = Rank 100 Precision : 0.29 (29/100)
#
# random = Rank 100 Recall    : 0.058823529411764705 (16/272)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11764705882352941 (32/272)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.07720588235294118 (21/272)
# random = Rank 100 Precision : 0.21 (21/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11764705882352941 (32/272)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.07352941176470588 (20/272)
# random = Rank 100 Precision : 0.2 (20/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11764705882352941 (32/272)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.04411764705882353 (12/272)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10661764705882353 (29/272)
# model  = Rank 100 Precision : 0.29 (29/100)
#
# random = Rank 100 Recall    : 0.10294117647058823 (28/272)
# random = Rank 100 Precision : 0.28 (28/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11764705882352941 (32/272)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.051470588235294115 (14/272)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11764705882352941 (32/272)
# model  = Rank 100 Precision : 0.32 (32/100)
#
# random = Rank 100 Recall    : 0.051470588235294115 (14/272)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10661764705882353 (29/272)
# model  = Rank 100 Precision : 0.29 (29/100)
#
# random = Rank 100 Recall    : 0.051470588235294115 (14/272)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11891891891891893 (22/185)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.04864864864864865 (9/185)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11351351351351352 (21/185)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.06486486486486487 (12/185)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11891891891891893 (22/185)
# model  = Rank 100 Precision : 0.22 (22/100)
#
# random = Rank 100 Recall    : 0.043243243243243246 (8/185)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11351351351351352 (21/185)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.043243243243243246 (8/185)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11351351351351352 (21/185)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.05945945945945946 (11/185)
# random = Rank 100 Precision : 0.11 (11/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11351351351351352 (21/185)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.04864864864864865 (9/185)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11351351351351352 (21/185)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.0918918918918919 (17/185)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11351351351351352 (21/185)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.05405405405405406 (10/185)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.11351351351351352 (21/185)
# model  = Rank 100 Precision : 0.21 (21/100)
#
# random = Rank 100 Recall    : 0.04864864864864865 (9/185)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07511737089201878 (16/213)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.056338028169014086 (12/213)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07511737089201878 (16/213)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.03755868544600939 (8/213)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06572769953051644 (14/213)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.056338028169014086 (12/213)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07042253521126761 (15/213)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.07042253521126761 (15/213)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07511737089201878 (16/213)
# model  = Rank 100 Precision : 0.16 (16/100)
#
# random = Rank 100 Recall    : 0.056338028169014086 (12/213)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06572769953051644 (14/213)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.07511737089201878 (16/213)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07981220657276995 (17/213)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.06103286384976526 (13/213)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07981220657276995 (17/213)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.07981220657276995 (17/213)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.07981220657276995 (17/213)
# model  = Rank 100 Precision : 0.17 (17/100)
#
# random = Rank 100 Recall    : 0.07042253521126761 (15/213)
# random = Rank 100 Precision : 0.15 (15/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06572769953051644 (14/213)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.07981220657276995 (17/213)
# random = Rank 100 Precision : 0.17 (17/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.06572769953051644 (14/213)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.06103286384976526 (13/213)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09740259740259741 (15/154)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.08441558441558442 (13/154)
# random = Rank 100 Precision : 0.13 (13/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09740259740259741 (15/154)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.1038961038961039 (16/154)
# random = Rank 100 Precision : 0.16 (16/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09740259740259741 (15/154)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.03896103896103896 (6/154)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09740259740259741 (15/154)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.032467532467532464 (5/154)
# random = Rank 100 Precision : 0.05 (5/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09090909090909091 (14/154)
# model  = Rank 100 Precision : 0.14 (14/100)
#
# random = Rank 100 Recall    : 0.09090909090909091 (14/154)
# random = Rank 100 Precision : 0.14 (14/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09740259740259741 (15/154)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.05844155844155844 (9/154)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09740259740259741 (15/154)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.045454545454545456 (7/154)
# random = Rank 100 Precision : 0.07 (7/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.09740259740259741 (15/154)
# model  = Rank 100 Precision : 0.15 (15/100)
#
# random = Rank 100 Recall    : 0.06493506493506493 (10/154)
# random = Rank 100 Precision : 0.1 (10/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10236220472440945 (13/127)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.03937007874015748 (5/127)
# random = Rank 100 Precision : 0.05 (5/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10236220472440945 (13/127)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.07086614173228346 (9/127)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10236220472440945 (13/127)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.023622047244094488 (3/127)
# random = Rank 100 Precision : 0.03 (3/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10236220472440945 (13/127)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.06299212598425197 (8/127)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10236220472440945 (13/127)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.07086614173228346 (9/127)
# random = Rank 100 Precision : 0.09 (9/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.10236220472440945 (13/127)
# model  = Rank 100 Precision : 0.13 (13/100)
#
# random = Rank 100 Recall    : 0.09448818897637795 (12/127)
# random = Rank 100 Precision : 0.12 (12/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08870967741935484 (11/124)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.06451612903225806 (8/124)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08064516129032258 (10/124)
# model  = Rank 100 Precision : 0.1 (10/100)
#
# random = Rank 100 Recall    : 0.06451612903225806 (8/124)
# random = Rank 100 Precision : 0.08 (8/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08064516129032258 (10/124)
# model  = Rank 100 Precision : 0.1 (10/100)
#
# random = Rank 100 Recall    : 0.03225806451612903 (4/124)
# random = Rank 100 Precision : 0.04 (4/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08870967741935484 (11/124)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.04838709677419355 (6/124)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08870967741935484 (11/124)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.04838709677419355 (6/124)
# random = Rank 100 Precision : 0.06 (6/100)
#
# top N  = 100 -------------------
#
# model  = Rank 100 Recall    : 0.08870967741935484 (11/124)
# model  = Rank 100 Precision : 0.11 (11/100)
#
# random = Rank 100 Recall    : 0.04838709677419355 (6/124)
# random = Rank 100 Precision : 0.06 (6/100)
#
# mAP@100 = 0.1872009472508236
# rmAP@100 = 0.12183775140522979
